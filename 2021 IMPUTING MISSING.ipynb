# %% [markdown]
# # IMPUTING MISSING

# %%
from sklearn.impute import SimpleImputer

import pandas as pd
import numpy as np
import random as rd

# %%
tamanho = 20
rd.seed = 42

sx = [rd.sample(['F', 'M'], 1)[0] for _ in range(tamanho)]
idade = [rd.sample(list(range(18, 75)), 1)[0] for _ in range(tamanho)]
classe = [rd.sample(['A', 'B', 'C'], 1)[0] for _ in range(tamanho)]

dic = {'sexo': sx, 'idade': idade, 'classe': classe}

dados = pd.DataFrame(dic)
dados.sample(5)
# Out:
#    sexo  idade classe
# 4     F     53      B
# 3     F     38      C
# 5     M     35      A
# 15    M     30      C
# 11    M     53      B

# %%
for linha in rd.sample(list(dados.index), 10):
  coluna = rd.sample([0, 1, 2], 1)[0]
  dados.iloc[linha, coluna] = np.NaN

dados
# Out:
#    sexo  idade classe
# 0     M   20.0      C
# 1   NaN   64.0      B
# 2     M   57.0    NaN
# 3     F   38.0      C
# 4     F   53.0      B
# 5     M   35.0    NaN
# 6   NaN   64.0      C
# 7     M   60.0    NaN
# 8   NaN   57.0      C
# 9     F   18.0      B
# 10    F   41.0      C
# 11    M   53.0    NaN
# 12    M   55.0      C
# 13    F   20.0      C
# 14    F   45.0      B
# 15    M   30.0      C
# 16  NaN   22.0      C
# 17    M   61.0      A
# 18    F    NaN      A
# 19    F   68.0    NaN

# %%
dados.isna().sum()
# Out:
# sexo      4
# idade     1
# classe    5
# dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sexo    16 non-null     object
#  1   idade   19 non-null     float64
#  2   classe  15 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 608.0+ bytes

# %%
imput = SimpleImputer(missing_values=np.NaN, strategy='median')
newimput = imput.fit_transform(dados['idade'].values.reshape(-1,1))[:, 0]
newimput
# Out:
# array([20., 64., 57., 38., 53., 35., 64., 60., 57., 18., 41., 53., 55.,
#        20., 45., 30., 22., 61., 53., 68.])

# %%
imputer = SimpleImputer(missing_values=np.NaN, strategy='most_frequent')
imputer.fit_transform(dados['sexo'].values.reshape(-1,1))[:,0]
# Out:
# array(['M', 'M', 'M', 'F', 'F', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'F', 'F'], dtype=object)

# %%
imputer = SimpleImputer(missing_values=np.NaN, strategy='constant', fill_value='F')
imputer.fit_transform(dados['sexo'].values.reshape(-1,1))[:,0]
# Out:
# array(['M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'M', 'M', 'M',
#        'M', 'F', 'M', 'M', 'M', 'F', 'F'], dtype=object)

# %%
imputer = SimpleImputer(missing_values=np.NaN, strategy='most_frequent')
imputer.fit_transform(dados['classe'].values.reshape(-1,1))[:,0]
# Out:
# array(['B', 'A', 'A', 'B', 'A', 'C', 'A', 'A', 'A', 'A', 'C', 'A', 'A',
#        'C', 'C', 'B', 'B', 'A', 'A', 'B'], dtype=object)

# %%
imputer.fit_transform(dados[['classe']])
# Out:
# array([['B'],
#        ['A'],
#        ['A'],
#        ['B'],
#        ['A'],
#        ['C'],
#        ['A'],
#        ['A'],
#        ['A'],
#        ['A'],
#        ['C'],
#        ['A'],
#        ['A'],
#        ['C'],
#        ['C'],
#        ['B'],
#        ['B'],
#        ['A'],
#        ['A'],
#        ['B']], dtype=object)

# %%
[['a'], ['a']]
# Out:
# [['a'], ['a']]
